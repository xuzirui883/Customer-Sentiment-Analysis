# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 KB 2.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting tqdm>4
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 8.6 MB/s eta 0:00:00
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 KB 13.0 MB/s eta 0:00:00
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.local/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.local/lib/python3.10/site-packages (from openai) (4.0.0)
# Requirement already satisfied: sniffio in ./.local/lib/python3.10/site-packages (from openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.1.3)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi in ./.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 11.4 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.3
#   Downloading pydantic_core-2.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tqdm, pydantic-core, h11, annotated-types, pydantic, httpcore, httpx, openai
# Successfully installed annotated-types-0.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.2 pydantic-2.6.4 pydantic-core-2.16.3 tqdm-4.66.2

# %%
# !pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio
#   Downloading gradio-4.25.0-py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 34.7 MB/s eta 0:00:0000:0100:01
# Collecting uvicorn>=0.14.0
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 KB 7.1 MB/s eta 0:00:00
# Collecting typer[all]<1.0,>=0.9
#   Downloading typer-0.12.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 KB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.0 in ./.local/lib/python3.10/site-packages (from gradio) (2.6.4)
# Collecting pillow<11.0,>=8.0
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 36.7 MB/s eta 0:00:0000:0100:01
# Collecting tomlkit==0.12.0
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions~=4.0 in ./.local/lib/python3.10/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: jinja2<4.0 in ./.local/lib/python3.10/site-packages (from gradio) (3.1.2)
# Collecting ruff>=0.2.2
#   Downloading ruff-0.3.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 36.3 MB/s eta 0:00:0000:0100:01
# Collecting semantic-version~=2.0
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting gradio-client==0.15.0
#   Downloading gradio_client-0.15.0-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 KB 42.1 MB/s eta 0:00:00
# Collecting matplotlib~=3.0
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 38.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/lib/python3/dist-packages (from gradio) (5.4.1)
# Collecting ffmpy
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandas<3.0,>=1.0
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 35.6 MB/s eta 0:00:0000:0100:01
# Collecting aiofiles<24.0,>=22.0
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting python-multipart>=0.0.9
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting altair<6.0,>=4.2.0
#   Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 KB 32.1 MB/s eta 0:00:00
# Collecting fastapi
#   Downloading fastapi-0.110.1-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 KB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy~=1.0 in ./.local/lib/python3.10/site-packages (from gradio) (1.26.0)
# Requirement already satisfied: markupsafe~=2.0 in ./.local/lib/python3.10/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: packaging in ./.local/lib/python3.10/site-packages (from gradio) (23.1)
# Requirement already satisfied: httpx>=0.24.1 in ./.local/lib/python3.10/site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.19.3
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 KB 50.1 MB/s eta 0:00:00
# Collecting importlib-resources<7.0,>=1.3
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting orjson~=3.0
#   Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 KB 20.6 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 KB 25.5 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 KB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=3.0 in ./.local/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.1)
# Collecting toolz
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: httpcore==1.* in ./.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in ./.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: anyio in ./.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (4.0.0)
# Requirement already satisfied: certifi in ./.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: sniffio in ./.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: tqdm>=4.42.1 in ./.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Collecting filelock
#   Downloading filelock-3.13.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 36.5 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 KB 56.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib~=3.0->gradio) (2.4.7)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.6 MB/s eta 0:00:0000:010:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 31.9 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-core==2.16.3 in ./.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# WARNING: typer 0.12.1 does not provide the extra 'all'
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 5.4 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 45.6 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: attrs>=22.2.0 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.local/lib/python3.10/site-packages (from rich>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.local/lib/python3.10/site-packages (from anyio->httpx>=0.24.1->gradio) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.5)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5600 sha256=e06a9a07a873aad915f33864ecc4cd3d4143663002d283e7568b064d1ffcdaf7
#   Stored in directory: /home/mt2shar/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pytz, pydub, ffmpy, websockets, tzdata, toolz, tomlkit, shellingham, semantic-version, ruff, python-multipart, pillow, orjson, mdurl, kiwisolver, importlib-resources, fsspec, fonttools, filelock, cycler, contourpy, click, aiofiles, uvicorn, starlette, pandas, matplotlib, markdown-it-py, huggingface-hub, rich, gradio-client, fastapi, typer, altair, gradio
# Successfully installed aiofiles-23.2.1 altair-5.3.0 click-8.1.7 contourpy-1.2.1 cycler-0.12.1 fastapi-0.110.1 ffmpy-0.3.2 filelock-3.13.3 fonttools-4.51.0 fsspec-2024.3.1 gradio-4.25.0 gradio-client-0.15.0 huggingface-hub-0.22.2 importlib-resources-6.4.0 kiwisolver-1.4.5 markdown-it-py-3.0.0 matplotlib-3.8.4 mdurl-0.1.2 orjson-3.10.0 pandas-2.2.1 pillow-10.3.0 pydub-0.25.1 python-multipart-0.0.9 pytz-2024.1 rich-13.7.1 ruff-0.3.5 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tomlkit-0.12.0 toolz-0.12.1 typer-0.12.1 tzdata-2024.1 uvicorn-0.29.0 websockets-11.0.3

# %%
from openai import OpenAI
import pandas as pd
client = OpenAI(api_key='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')

def time_sensitivity(sentence):
  completion = client.chat.completions.create(
      model='gpt-3.5-turbo',
      messages=[
        {"role": "system",
         "content": "Give me the time sensitivity of the following sentences. Using 1 word like 'High', 'Low' or 'Medium' to cover all the sentences. Using 'High' or 'Low' more."},
        {"role": "user",
         "content": sentence}
      ],
      temperature=0.5,
      top_p=0.5,
  )
  return completion.choices[0].message.content

def importance(sentence):
  completion = client.chat.completions.create(
      model='gpt-3.5-turbo',
      messages=[
        {"role": "system",
         "content": "Give me the urgency of the event of the following sentences. Using 1 word like 'High', 'Low' or 'Medium' to cover all the sentences. Using 'High' or 'Low' more."},
        {"role": "user",
         "content": sentence}
      ],
      temperature=0.5,
      top_p=0.5,
  )
  return completion.choices[0].message.content

def tone(sentence):
  completion = client.chat.completions.create(
      model='gpt-3.5-turbo',
      messages=[
        {"role": "system",
         "content": "Give me the urgency conveys by tone conveys of the following sentences. Using 1 word like 'High', 'Low' or 'Medium' to cover all the sentences. Using 'High' or 'Low' more."},
        {"role": "user",
         "content": sentence}
      ],
      temperature=0.5,
      top_p=0.5,
  )
  return completion.choices[0].message.content

def score(level):

  if level == 'High':
    out = 5
  elif level == 'Medium':
    out = 3
  else:
    out = 1

  return out

def check_all(sentence):

  time_sen = time_sensitivity(sentence)
  # print(time_sen)
  time_sen = score(time_sensitivity(sentence)) * 0.5

  impor = importance(sentence)
  # print(impor)
  impor = score(importance(sentence)) * 0.3

  to = tone(sentence)
  # print(to)
  to = score(tone(sentence)) * 0.2

  return round(time_sen + impor + to)

# %%
import gradio as gr
#from Sentiment_model import time_sensitivity, importance, tone, check_all

def ece1779(sentence):

  tim = time_sensitivity(sentence)
  imp = importance(sentence)
  ton = tone(sentence)
  result = check_all(sentence)

  return tim, imp, ton, result

project = gr.Interface(
    fn=ece1779,
    inputs=[gr.Textbox(lines=50, placeholder="Type here the sentences...")],
    outputs=[gr.Textbox(label='Time Urgency'), gr.Textbox(label='Event Urgency'), gr.Textbox(label='Language Excitement'), gr.Textbox(label='Urgency Rating')]
)

# %%
project.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
